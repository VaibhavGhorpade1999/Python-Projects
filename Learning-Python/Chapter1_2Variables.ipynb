# %% [markdown]
# ## Variables

# %% [markdown]
# Every Variable holds the value which is information associated with it
#
# e.g variable = message

# %%
message="hello World"

# %% [markdown]
# ## Data Types:

# %% [markdown]
# # 1)Strings
# it is simply a series of character.
#
# e.g "hello World" is string

# %%
message="hello World"

# %% [markdown]
# a)Changing Case of strings with methods

# %%
first_name= "vaibhav"
print(first_name.title())
print(first_name.upper())
print(first_name.lower())
# Out:
# Vaibhav
# VAIBHAV
# vaibhav

# %% [markdown]
# b)Combining or concentrating Strings- To combine two or more strings

# %%
first_name= "vaibhav"
last_name= "ghorpade"
full_name= first_name+ " " +last_name
print(full_name.title())
# Out:
# Vaibhav Ghorpade

# %% [markdown]
# c)Adding Whitespace to Strings with Tabs or Newlines

# %%
print("Languages:\nPython\n\tC\n\t\tJavaScript")
# Out:
# Languages:
# Python
# 	C
# 		JavaScript

# %% [markdown]
# d)Stripping Whitespace
#   1)Right
#   2)Left
#   3)Both

# %%
first_name=" Vaibhav "
print(first_name)
print(first_name.rstrip())
print(first_name.lstrip())
print(first_name.strip())
# Out:
#  Vaibhav
#  Vaibhav
# Vaibhav
# Vaibhav

# %% [markdown]
# e)Avoiding Syntax Errors with Strings

# %% [markdown]
# without error

# %%
message = "One of Python's strengths is its diverse community." 
print(message)
# Out:
# One of Python's strengths is its diverse community.

# %% [markdown]
# with error

# %%
message = 'One of Python's strengths is its diverse community' 
print(message)
# Out:
#   File "<ipython-input-18-aad8bdfb2e9e>", line 1
#     message = 'One of Python's strengths is its diverse community'
#                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 2)Numbers

# %% [markdown]
# Numbers are used quite often in programming to keep score in games, represent data in visualizations, store information in web applications, and so
# on

# %% [markdown]
# a)Integers

# %%
2+3
# Out:
# 6

# %%
5-3
# Out:
# 2

# %%
5*3
# Out:
# 15

# %%
5/5
# Out:
# 1.0

# %%
5**2
# Out:
# 125

# %%
5**5
# Out:
# 3125

# %%
5+3*2
# Out:
# 11

# %%
(5+3)*2
# Out:
# 16

# %% [markdown]
#  b)Floats

# %% [markdown]
# Python calls any number with a decimal point a float. This term is used in
# most programming languages, and it refers to the fact that a decimal point
# can appear at any position in a number.

# %%
0.1+0.1
# Out:
# 0.2

# %%
0.005*2
# Out:
# 0.01

# %% [markdown]
# *Avoiding Type Errors with the str() Function*

# %%
age =23
message= "Its my "+ age+ "rd Birthday"
print(message)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-13ebc7cd82e2> in <module>
#       1 age =23
# ----> 2 message= "Its my "+ age+ "rd Birthday"
#       3 print(message)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Python knows that the variable could represent either the numerical
# value 23 or the characters 2 and 3. When you use integers within strings
# like this, you need to specify explicitly that you want Python to use the integer as a string of characters. You can do this by wrapping the variable in the
# str() function, which tells Python to represent non-string values as string

# %%
age =23
message= "Its my "+ str(age)+ "rd Birthday"
print(message)
# Out:
# Its my 23rd Birthday

# %%
print(4+4)
print(4*2)
print(16/2)
print(12-4)
variable="25"
print("my favorite number is "+ variable)
variable_2=25
print("my favorite number is "+ str(variable_2))
# Out:
# 8
# 8
# 8.0
# 8
# my favorite number is 25
# my favorite number is 25

# %% [markdown]
# comments= the hash mark (#) indicates a comment

# %%
# Say hello to everyone.
print("Hello Python people!")
# Out:
# Hello Python people!
