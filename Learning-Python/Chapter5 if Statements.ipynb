# %% [markdown]
# # if Statements
# Programming often involves examining
# a set of conditions and deciding which
# action to take based on those conditions.
# Python’s if statement allows you to examine the
# current state of a program and respond appropriately
# to that state

# %%
cars = ['audi', 'bmw', 'subaru', 'toyota']
for car in cars:
  if car == 'bmw':
    print("My favorite car is "+ car.upper())
  else:
    print(car.title()+" is not my favourite car")
# Out:
# Audi is not my favourite car
# My favorite car is BMW
# Subaru is not my favourite car
# Toyota is not my favourite car

# %% [markdown]
# ## Conditional Tests

# %%
cars='bmw'
print(cars=='bmw')
print(cars=='audi')
#Ignoring Case When Checking for Equality
print(cars=='Bmw')
cars.title()=="Bmw"
print(cars)
# Out:
# True
# False
# False
# bmw

# %%
#Checking for Inequality
requested_topping = 'mushrooms'
if requested_topping == 'anchovies':
 print("Hold the anchovies!")
else:
 print("hold my mushrooms")
# Out:
# hold my mushrooms

# %% [markdown]
# ### Numerical Comparisons

# %%
age=42
print(age==18)
if age!=18:
  print("That's not my correct age, please try again")

print(age<21)
print(age>21)
print(age<=21)
print(age>=21)
# Out:
# False
# That's not my correct age, please try again
# False
# True
# False
# True

# %%
#Checking Multiple Conditions
age1=22
age2=34
print(age1>21 and age2>21)
print(age1>21 and age2>35)
age2=36
print(age1>21 and age2>35)
print(age1>23 or age2>35)
# Out:
# True
# False
# True
# True

# %%
#checking whether value is in list
cars = ['audi', 'bmw', 'subaru', 'toyota']
print('audi'in cars)
print('safari' in cars)
#checking whether value is not in the list
banned_user=['vaibhav','shubham','vandana']
user='arvind'
if user not in banned_user:
  print("Hello "+ user.title()+ "! You are allowed to fill the exam form")
# Out:
# True
# False
# Hello Arvind! You are allowed to fill the exam form

# %% [markdown]
# ## Boolean Expression
# Boolean values are often used to keep track of certain conditions, such
# as whether a game is running or whether a user can edit certain content on
# a website
# game_active = True
# can_edit = False

# %% [markdown]
# ## if Statements

# %%
age= 23
print(age)
if age>=18:
  print("you are allowed in bar")
else:
  print("you are not allowed in bar")
# Out:
# 23
# you are allowed in bar

# %% [markdown]
# ## The if-elif-else Chain
# Often, you’ll need to test more than two possible situations, and to evaluate
# these you can use Python’s if-elif-else syntax

# %%
age=18
if age < 4:
 print("Your admission cost is $0.")
elif age < 18:
 print("Your admission cost is $5.")
else:
 print("Your admission cost is $10.")
# Out:
# Your admission cost is $10.

# %%
#shortcut method
age=16
if age<4:
  price=0
elif age<18:
  price=5
else:
  price=10
print("your admission cost is "+ str(price))
# Out:
# your admission cost is 5

# %%
#Omitting the else Block
#Python does not require an else block at the end of an if-elif chain. Sometimes an else block is useful; sometimes it is clearer to use an additional elif statement that catches the specific condition of interest
age = 12
if age < 4:
 price = 0
elif age < 18:
 price = 5
elif age < 65:
 price = 10
elif age >= 65:
 price = 5
print("Your admission cost is $" + str(price) + ".")
# Out:
# Your admission cost is $5.

# %% [markdown]
# ## Testing Multiple Conditions

# %%
requested_toppings = ['mushrooms', 'extra cheese']
if 'mushrooms' in requested_toppings:
 print("Adding mushrooms.")
if 'pepperoni' in requested_toppings:
 print("Adding pepperoni.")
if 'extra cheese' in requested_toppings:
 print("Adding extra cheese.")
 
print("\nFinished making your pizza!")
# Out:
# Adding mushrooms.
# Adding extra cheese.
#
# Finished making your pizza!

# %% [markdown]
# ## Using if Statements with Lists

# %%
requested_toppings = ['mushrooms', 'green peppers', 'extra cheese']
for requested_topping in requested_toppings:
  if 'green peppers'in requested_topping:
   print("Sorry, we are out of green peppers right now.")
  else:
   print("Adding " + requested_topping + ".")
print("\nFinished making your pizza!")
# Out:
# Adding mushrooms.
# Sorry, we are out of green peppers right now.
# Adding extra cheese.
#
# Finished making your pizza!

# %% [markdown]
# ## Using Multiple Lists

# %%
available_toppings = ['mushrooms', 'olives', 'green peppers','pepperoni', 'pineapple', 'extra cheese']
requested_toppings = ['mushrooms', 'french fries', 'extra cheese']
for requested_topping in requested_toppings:
  if requested_topping in available_toppings:
    print("Adding " + requested_topping + ".")
  else:
    print("Sorry, we don't have " + requested_topping + ".")
 
print("\nFinished making your pizza!")
# Out:
# Adding mushrooms.
# Sorry, we don't have french fries.
# Adding extra cheese.
#
# Finished making your pizza!
