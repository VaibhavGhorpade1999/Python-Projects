# %% [markdown]
# # Chapter 3 Introducing Lists

# %% [markdown]
# Lists allow you to store
# sets of information in one place, whether you
# have just a few items or millions of items. Lists are
# one of Python’s most powerful features readily accessible to new programmers, and they tie together many
# important concepts in programming.
# ### A list is a collection of items in a particular order
# In Python, square brackets ([]) indicate a list, and individual elements
# in the list are separated by commas

# %%
bicycles = ["trek", "cannondale", 'redline', 'specialized']
print(bicycles)
# Out:
# ['trek', 'cannondale', 'redline', 'specialized']

# %% [markdown]
# ### a)Accessing Elements in a List

# %%
Lists are ordered collections, so you can access any element in a list by 
telling Python the position, or index, of the item desired.

# %%
bicycles = ["trek", "cannondale", ' redline ', 'specialized']
print(bicycles[0])
print(bicycles[1])
print(bicycles[2].rstrip())
print(bicycles[2].title())
print(bicycles[-2])
# Out:
# trek
# cannondale
#  redline
#  Redline
#  redline

# %% [markdown]
# ## b)Using Individual Values from a List

# %%
bicycles = ["trek", "cannondale", ' redline ', 'specialized']
message= "My first bicycle was a "+ bicycles[2].title()
print(message)
# Out:
# My first bicycle was a  Redline

# %%
names = ['Vaibhav','Shubham','Arvind','Vandana']
print("hello "+names[0] +"! How are you?")
print("hello "+names[1] +"! How are you?")
print("hello "+names[2] +"! How are you?")
print("hello "+names[3] +"! How are you?")
# Out:
# hello Vaibhav! How are you?
# hello Shubham! How are you?
# hello Arvind! How are you?
# hello Vandana! How are you?

# %% [markdown]
# ## c)Changing, Adding, and Removing Elements

# %%
names = ['Vaibhav','Shubham','Arvind','Vandana']
print(names)
names[0]='Akshay'
print(names)
names.append('Shailesh')
print(names)
names.insert(2, 'mahadev')
print(names)
len(names)
#Removing an Item Using the del Method
del names[0]
print(names)
len(names)
#Removing an Item Using the pop() Method
#The pop() method removes the last item in a list, but it lets you work with that item after removing it. 
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)
a= motorcycles.pop(1) #we can keep bracket void if we want to pop last item of list
print(motorcycles)
print(a)
#Removing an Item Using the value Method
motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati'] 
print(motorcycles)
motorcycles.remove('ducati')
print(motorcycles)
# Out:
# ['Vaibhav', 'Shubham', 'Arvind', 'Vandana']
# ['Akshay', 'Shubham', 'Arvind', 'Vandana']
# ['Akshay', 'Shubham', 'Arvind', 'Vandana', 'Shailesh']
# ['Akshay', 'Shubham', 'mahadev', 'Arvind', 'Vandana', 'Shailesh']
# ['Shubham', 'mahadev', 'Arvind', 'Vandana', 'Shailesh']
# ['honda', 'yamaha', 'suzuki']
# ['honda', 'suzuki']
# yamaha
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'suzuki']

# %% [markdown]
# ## d)Organizing a List

# %%
#Sorting a List Permanently with the sort() Method
#The sort() method, shown at u, changes the order of the list permanently. The cars are now in alphabetical order, and we can never revert to the original order
cars=['audi','bugati','bmw','andro','maruti']
cars.sort()
print(cars)
cars.sort(reverse=True)     #reverse Order
print(cars)
# Out:
# ['andro', 'audi', 'bmw', 'bugati', 'maruti']
# ['maruti', 'bugati', 'bmw', 'audi', 'andro']

# %%
#Sorting a List Temporarily with the sorted() Function
#To maintain the original order of a list but present it in a sorted order, you can use the sorted() function. The sorted() function lets you display your list in a particular order but doesn’t affect the actual order of the list.
cars=['audi','bugati','bmw','andro','maruti']
print("here is the list of sorted cars  ")
print(sorted(cars))
print("here is the original list")
print(cars)
cars.sort(reverse=True)
print(cars)
print(cars)
# Out:
# here is the list of sorted cars
# ['andro', 'audi', 'bmw', 'bugati', 'maruti']
# here is the original list
# ['audi', 'bugati', 'bmw', 'andro', 'maruti']
# ['maruti', 'bugati', 'bmw', 'audi', 'andro']
# ['maruti', 'bugati', 'bmw', 'audi', 'andro']

# %%
#Printing a List in Reverse Order
cars=['audi','bugati','bmw','andro','maruti']
print(cars)
cars.reverse()
print(cars)
#Finding the Length of a List
len(cars)
# Out:
# ['audi', 'bugati', 'bmw', 'andro', 'maruti']
# ['maruti', 'andro', 'bmw', 'bugati', 'audi']
# 5

# %% [markdown]
# ## Avoiding Index Errors When Working with Lists

# %% [markdown]
# One type of error is common to see when you’re working with lists for the
# first time.

# %%
motorcycles = ['honda', 'yamaha', 'suzuki'] 
print(motorcycles[3])            #3 is out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-da0e532e95ce> in <module>
#       1 motorcycles = ['honda', 'yamaha', 'suzuki']
# ----> 2 print(motorcycles[3])            #3 is out of range
#
# IndexError: list index out of range
